# %%
import pandas as pd

# %%
pokemon_df = pd.read_csv("pokemon.csv", index_col=0)
print(f'Unique primary types: {pokemon_df["type1"].nunique()}')
print(f'Unique secondary types: {pokemon_df["type2"].nunique()}')
df.head()
pokemon_df = pokemon_df.dropna()
df.dropna(axis="columns",how="any").shape
# Out:
# Unique primary types: 18
# Unique secondary types: 18
# (801, 41)

# %%
pokemon_df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   339.000000    339.000000      339.000000        339.000000
# mean      0.900442      1.009587        0.961652          1.166667
# std       0.648057      0.406698        0.394119          0.803714
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          2.000000
# max       4.000000      2.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     339.000000     339.000000    339.000000      339.000000
# mean        1.090708       1.023599      1.229351        1.283923
# std         0.639892       0.874839      0.829567        0.700507
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
project_name = "pokemon data analysis with python"

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 339 entries, ['Overgrow', 'Chlorophyll'] to ['Bulletproof', 'Soundproof', 'Overcoat']
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   against_bug        339 non-null    float64
#  1   against_dark       339 non-null    float64
#  2   against_dragon     339 non-null    float64
#  3   against_electric   339 non-null    float64
#  4   against_fairy      339 non-null    float64
#  5   against_fight      339 non-null    float64
#  6   against_fire       339 non-null    float64
#  7   against_flying     339 non-null    float64
#  8   against_ghost      339 non-null    float64
#  9   against_grass      339 non-null    float64
#  10  against_ground     339 non-null    float64
#  11  against_ice        339 non-null    float64
#  12  against_normal     339 non-null    float64
#  13  against_poison     339 non-null    float64
# ...

# %%
import jovian
jovian.commit(project=project_name)
# Out:
# [jovian] Creating a new project "fuadeedu/pokemon data analysis with python"
# [jovian] Committed successfully! https://jovian.ai/fuadeedu/pokemon-data-analysis-with-python
# 'https://jovian.ai/fuadeedu/pokemon-data-analysis-with-python'

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.tail()
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
df.isnull().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
df['height_m'].fillna(df['height_m'].mean(), inplace=True)

df['type2'].fillna('None', inplace=True)

df['weight_kg'].fillna(df['weight_kg'].mean(), inplace=True)

df['percentage_male'].fillna('None', inplace=True)

df.insert(0, 'name', df.pop('name'))

# %%
df.isnull().sum()
#böylelikle hatasız ilerliyor csv dosyamız
# Out:
# name                 0
# abilities            0
# against_bug          0
# against_dark         0
# against_dragon       0
# against_electric     0
# against_fairy        0
# against_fight        0
# against_fire         0
# against_flying       0
# against_ghost        0
# against_grass        0
# against_ground       0
# against_ice          0
# against_normal       0
# against_poison       0
# against_psychic      0
# against_rock         0
# against_steel        0
# against_water        0
# attack               0
# base_egg_steps       0
# base_happiness       0
# base_total           0
# capture_rate         0
# classfication        0
# defense              0
# experience_growth    0
# height_m             0
# hp                   0
# japanese_name        0
# percentage_male      0
# pokedex_number       0
# sp_attack            0
# sp_defense           0
# speed                0
# type1                0
# type2                0
# weight_kg            0
# generation           0
# ...

# %%
top_5 = df.sort_values(by="name", ascending=False).head()
top_5.plot(x="name", y="attack", kind="bar", rot=8, fontsize=6)
# Out:
# <AxesSubplot:xlabel='name'>

# %%
top_pokemon = df[df["attack"] > 150].sort_values("hp")

top_pokemon.plot(x="name", y=["defense", "hp"], kind="bar")

#en güçlü saldırı ve savunma değerleri olan pokemonları görüyoruz
# Out:
# <AxesSubplot:xlabel='name'>

# %%
plt.figure(figsize=(6,4))
fd = sns.countplot(x='generation', data=df,order=df['generation'].value_counts().index)
fd.set_title('Jenerasyona göre pokemon sayısı')
fd.set(xlabel='Jenerasyon', ylabel='Veri')
#her jenerasyonda eklenen pokemon sayısının değiştiğini grafiğe göre anlayabiliyoruz
# Out:
# [Text(0.5, 0, 'Jenerasyon'), Text(0, 0.5, 'Veri')]

# %%
against=[]
rest=[]
for i in df.columns:
    if 'against' in i:
        against.append(i)
    else:
        rest.append(i)
        
#şimdi saldırı oranlarını bir oyunda gibi inceleyelim

fig,axes = plt.subplots(figsize=(16,10))
sns.heatmap(df[against].corr(), annot=True).set_title('Saldırı oranları')
plt.show()

# %%
f, axes = plt.subplots(1,4,figsize=(18,4),sharey=True)

sns.scatterplot(df['speed'],df['height_m'],ax=axes[0])
sns.scatterplot(df['attack'],df['height_m'],ax=axes[1])
sns.scatterplot(df['defense'],df['height_m'],ax=axes[2])
sns.scatterplot(df['hp'],df['height_m'],ax=axes[3])

#pokemonların saldırı savunma veya can değerlerinin boylarıyla ilişkisinin analizi
# Out:
# C:\Users\Monster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Monster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Monster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
en10_pokemon_base_total = df.sort_values(by="base_total", ascending=False).reset_index()[:10]
plt.figure(figsize=(16,10))
ax = sns.barplot(x=top10_pokemon_base_total["name"], y=top10_pokemon_base_total["base_total"], orient='v')
ax.set_title("En iyi pokemonu arıyoruz", size=20)
ax.set(xlabel="Temel Güç", ylabel="İsim")
for p in ax.patches:
    ax.annotate('{:.1f}'.format( p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
